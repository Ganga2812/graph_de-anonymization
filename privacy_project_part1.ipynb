# %%
import networkx as nx
import math
import statistics

# %%
data_dir1 = r'C:\Users\Dan\(2) privacy\part1\\'
file1 = 'seed_G1.edgelist'

data_dir2 = r'C:\Users\Dan\(2) privacy\part1\\'
file2 = 'seed_G2.edgelist'

data_dir3 = r'C:\Users\Dan\(2) privacy\part1\\'
file3 = 'seed_node_pairs.txt'

# %%
G1 = nx.read_edgelist(data_dir1+file1, create_using=nx.Graph(), nodetype=int)

G2 = nx.read_edgelist(data_dir2+file2, create_using=nx.Graph(), nodetype=int)

print(nx.info(G1))
print("")
print(nx.info(G2))

arrayOfNodesG1 = list(nx.nodes(G1))

arrayOfNodesG2 = list(nx.nodes(G2))

seedPairG1 = []
seedPairG2 = []

with open(data_dir3+file3, "r") as text_file:
    for line in text_file:
        line = line.strip()
        number1 , number2 = line.split(" ")
        seedPairG1.append(int(number1))
        #first columns of matched nodes
        seedPairG2.append(int(number2))
        #second columns of matched nodes

unMatchedG1 = [x for x in arrayOfNodesG1 if (x not in seedPairG1)]
unMatchedG1.sort()
unMatchedG2 = [x for x in arrayOfNodesG2 if (x not in seedPairG2)]
# Out:
# Name:
# Type: Graph
# Number of nodes: 4563
# Number of edges: 159748
# Average degree:  70.0188
#
# Name:
# Type: Graph
# Number of nodes: 4563
# Number of edges: 159738
# Average degree:  70.0145
# [1684, 2600, 548, 386, 948, 3978, 4065, 220, 1262, 4396, 193, 4459, 385, 2894, 3385, 2345, 3324, 3201, 191, 1256, 312, 3335, 2723, 3755, 2694, 4516, 2322, 1460, 3997, 1704, 3122, 2489, 3069, 3479, 888, 3125, 4469, 2020, 1927, 3280, 2995, 1964, 2053, 1001, 53, 3585, 4451, 699, 3930, 2078, 2233, 1010, 1500, 97, 3037, 2742, 3, 1113, 3595, 1266, 2856, 3111, 2565, 3810, 495, 4298, 865, 2750, 320, 2903, 3670, 3367, 2811, 4462, 740, 1424, 2166, 2125, 523, 4317, 942, 138, 4384, 2389, 3327, 3477, 2059, 570, 2782, 4333, 3982, 592, 1227, 3732, 1095, 2918, 411, 1073, 4538, 4339, 4178, 214, 4134, 2249, 3358, 3110, 258, 4502, 2778, 1301, 1939, 3223, 2697, 4034, 904, 370, 2140, 1614, 2858, 1358, 2177, 4355, 227, 2314, 1022, 4108, 4400, 3228, 1093, 1063, 3803, 2216, 929, 976, 27, 3066, 1641, 638, 366, 2566, 707, 425, 2920, 4442, 2158, 1083, 1167, 3395, 1189, 2847, 199, 84, 4164, 4215, 2402, 1887, 4183, 3593, 1505, 2235, 1416, 1251, 742, 401, 1974, 133, 2494, 480, 4052, 3339, 1738, 246, 4406, 3432, 994, 3053, 1147, 1210, 3895, 3227, 4102, 281, 669, 3212, 4078, 4413, 4033, 2543, 4092, 2248, 1069, 4375, 982
1814, 2661, 240, 1435, 2816, 302, 3027, 3486, 1980, 977, 3736, 2017, 2362, 1200, 2250, 2924, 408, 2230, 1239, 716, 788, 3328, 3291, 3681, 4362, 8, 4534, 937, 2286, 787, 2487, 524, 4250, 559, 681, 3071, 4179, 1335, 1668, 1450, 2993, 1115, 1145, 1267, 1967, 4087, 1310, 4493, 688, 861, 1557, 4440, 4145, 422, 1602, 1384, 1877, 4126, 3976, 1621, 1618, 727, 4511, 4484, 1710, 3275, 2520, 1902, 1735, 2363, 2649, 1533, 3924, 3444, 3164, 1338, 316, 2395, 344, 545, 2707, 922, 205, 2734, 2333, 715, 2325, 1830, 766, 2621, 1570, 2861, 2905, 3671, 1739, 756, 1382, 3235, 2814, 4002, 3057, 2626, 457, 3329, 3675, 4280, 4246, 626, 855, 2745, 3504, 3224, 454, 4466, 2743, 1853, 3094, 4120, 3985, 2149, 3805, 4079, 3625, 981, 1436, 1134, 2371, 3413, 3619, 2348, 3318, 2469, 1170, 396, 2657, 30 ...

# %%
def calc(nonMatchedG1:list, nonMatchedG2:list):
    for x in nonMatchedG1:
        scoreList = []
        degreeOfV = len(list(nx.neighbors(G1, x)))
        print(x)
        for y in nonMatchedG2:
            count = 0
            degreeOfU = len(list(nx.neighbors(G2, y)))
            neighbors = list(nx.neighbors(G2, y))
            for nodeU in neighbors:
                for z in seedPairG2:
                    if nodeU == z:
                        count = count + 1
            score = (count)/(math.sqrt(degreeOfV) * math.sqrt(degreeOfU))
            scoreList.append(score)
        std = statistics.pstdev(scoreList)
        max1 = max(scoreList)
        scoreList.remove(max1)
        max2 = max(scoreList)
        ecce = (max1 - max2)/(std)
        print("Node V =", x)
        print("Scores =", scoreList)
        print("Std =", std)
        print("Max1 =", max1)
        print("Max2 =", max2)
        print("ECCE = (", max1, "-", max2, ") /", std, "=", ecce)
        print("Iteration:", number)
        print("ECCE =", ecce)
        print(" ")
        if ecce > 0:
            print(x, y)
            seedPairG1.append(x)
            seedPairG2.append(y)
            #nonMatchedG1.remove(x)
            nonMatchedG2.remove(y)
        print(" ")
        print("-----")
        print(" ")
    pass

# %%
calc(unMatchedG1, unMatchedG2)
# Out:
# 500
# 500 236
#
# -----
#
# 501
# 501 2331
#
# -----
#
# 502
# 502 4309
#
# -----
#
# 503
# 503 3563
#
# -----
#
# 504
# 504 2206
#
# -----
#
# 505
# 505 4264
#
# -----
#
# 506
# 506 2862
#
# -----
#
# 507
# 507 2665
#
# -----
#
# 508
# 508 382
#
# -----
#
# 509
# 509 2419
#
# -----
#
# 510
# 510 4233
#
# -----
#
# 511
# 511 3964
#
# -----
#
# 512
# 512 3370
#
# -----
#
# 513
# 513 2923
#
# -----
#
# 514
# 514 4110
#
# -----
#
# 515
# 515 3014
#
# -----
#
# 516
# 516 3488
#
# -----
#
# 517
# 517 4205
#
# -----
#
# 518
# 518 1110
#
# -----
#
# 519
# 519 663
#
# -----
#
# 520
# 520 3689
#
# -----
#
# 521
# 521 2071
#
# -----
#
# 522
# 522 635
#
# -----
#
# 523
# 523 333
#
# -----
#
# 524
# 524 4266
#
# -----
#
# 525
# 525 3107
#
# -----
#
# 526
# 526 2284
#
# -----
#
# 527
# 527 163
#
# -----
#
# 528
# 528 277
#
# -----
#
# 529
# 529 2733
#
# -----
#
# 530
# 530 934
#
# -----
#
# 531
# 531 1501
#
# -----
#
# 532
# 532 1142
#
# -----
#
# 533
# 533 3425
#
# -----
#
# 534
# 534 4310
#
# -----
#
# 535
# 535 2267
#
# -----
#
# 536
# 536 1674
#
# -----
#
# 537
# 537 1888
#
# -----
#
# 538
# 538 3103
#
# -----
#
# 539
# 539 1975
#
# -----
#
# 540
# 540 144
#
# -----
#
# 541
# 541 4038
#
# -----
#
# 542
# 542 961
#
# -----
#
# 543
# 543 3203
#
# -----
#
# 544
# 544 2254
#
# -----
#
# 545
# 545 1545
#
# -----
#
# 546
# 546 1284
#
# -----
#
# 547
# 547 3379
#
# -----
#
# 548
# 548 1821
#
# -----
#
# 549
# 549 4452
#
# -----
#
# 550
# 550 215
#
# -----
#
# 551
# 551 1127
#
# -----
#
# 552
# 552 1150
#
# -----
#
# 553
# 553 964
#
# -----
#
# 554
# 554 1696
#
# -----
#
# 555
# 555 2252
#
# -----
#
# 556
# 556 3759
#
# -----
#
# 557
# 557 1554
#
# -----
#
# 558
# 558 4464
#
# -----
#
# 559
# 559 643
#
# -----
#
# 560
# 560 358
#
# -----
#
# 561
# 561 2237
#
# -----
#
# 562
# 562 3784
#
# -----
#
# 563
# 563 1611
#
# -----
#
# 564
# 564 1053
#
# -----
#
# 565
# 565 1364
#
# -----
#
# 566
# 566 3796
#
# -----
#
# 567
# 567 3304
#
# -----
#
# 568
# 568 751
#
# -----
#
# 569
# 569 2056
#
# -----
#
# 570
# 570 2631
#
# -----
#
# 571
# 571 3980
#
# -----
#
# 572
# 572 4247
#
# -----
#
# 573
# 573 4525
#
# -----
#
# 574
# 574 3659
#
# -----
#
# 575
# 575 3029
#
# -----
#
# 576
# 576 307
#
# -----
#
# 577
# 577 4555
#
# -----
#
# 578
# 578 1945
#
# -----
#
# 579
# 579 1425
#
# -----
#
# 580
# 580 4132
#
# -----
#
# 581
# 581 3487
#
# -----
#
# 582
# 582 273
#
# -----
#
# 583
# 583 2798
#
# -----
#
# 584
# 584 2147
#
# -----
#
# 585
# 585 1535
#
# -----
#
# 586
# 586 218
#
# -----
#
# 587
# 587 4032
#
# -----
#
# 588
# 588 29
#
# -----
#
# 589
# 589 1528
#
# -----
#
# 590
# 590 3699
#
# -----
#
# 591
# 591 2196
#
# -----
#
# 592
# 592 1598
#
# -----
#
# 593
# 593 774
#
# -----
#
# 594
# 594 1242
#
# -----
#
# 595
# 595 1197
#
# -----
#
# 596
# 596 2372
#
# -----
#
# 597
# 597 3998
#
# -----
#
# 598
# 598 286
#
# -----
#
# 599
# 599 867
#
# -----
#
# 600
# 600 3763
#
# -----
#
# 601
# 601 4028
#
# -----
#
# 602
# 602 1567
#
# -----
#
# 603
# 603 1422
#
# -----
#
# 604
# 604 4490
#
# -----
#
# 605
# 605 692
#
# -----
#
# 606
# 606 2922
#
# -----
#
# 607
# 607 1076
#
# -----
#
# 608
# 608 3137
#
# -----
#
# 609
# 609 1745
#
# -----
#
# 610
# 610 3301
#
# -----
#
# 611
# 611 2603
#
# -----
#
# 612
# 612 2893
#
# -----
#
# 613
# 613 3232
#
# -----
#
# 614
# 614 870
#
# -----
#
# 615
# 615 1788
#
# -----
#
# 616
# 616 466
#
# -----
#
# 617
# 617 2871
#
# -----
#
# 618
# 618 2285
#
# -----
#
# 619
# 619 1955
#
# -----
#
# 620
# 620 1695
#
# -----
#
# 621
# 621 2701
#
# -----
#
# 622
# 622 4148
#
# -----
#
# 623
# 623 700
#
# -----
#
# 624
# 624 4210
#
# -----
#
# 625
# 625 2539
#
# -----
#
# 626
# 626 1889
#
# -----
#
# 627
# 627 1936
#
# -----
#
# 628
# 628 3273
#
# -----
#
# 629
# 629 156
#
# -----
#
# 630
# 630 2203
#
# -----
#
# 631
# 631 2958
#
# -----
#
# 632
# 632 1886
#
# -----
#
# 633
# 633 39
#
# -----
#
# 634
# 634 68
#
# -----
#
# 635
# 635 1669
#
# -----
#
# 636
# 636 3575
#
# -----
#
# 637
# 637 4361
#
# -----
#
# 638
# 638 1506
#
# -----
#
# 639
# 639 3295
#
# -----
#
# 640
# 640 2035
#
# -----
#
# 641
# 641 3522
#
# -----
#
# 642
# 642 252
#
# -----
#
# 643
# 643 2512
#
# -----
#
# 644
# 644 843
#
# -----
#
# 645
# 645 2153
#
# -----
#
# 646
# 646 650
#
# -----
#
# 647
# 647 2542
#
# -----
#
# 648
# 648 2444
#
# -----
#
# 649
# 649 3262
#
# -----
#
# 650
# 650 1482
#
# -----
#
# 651
# 651 2123
#
# -----
#
# 652
# 652 2172
#
# -----
#
# 653
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-0efde6491398> in <module>
# ----> 1 calc(unMatchedG1, unMatchedG2)
#
# <ipython-input-4-cbd8d5df4a99> in calc(nonMatchedG1, nonMatchedG2)
#      11                 for z in seedPairG2:
#      12                     if nodeU == z:
# ---> 13                         count = count + 1
#      14             score = (count)/(math.sqrt(degreeOfV) * math.sqrt(degreeOfU))
#      15             scoreList.append(score)
#
# KeyboardInterrupt:
